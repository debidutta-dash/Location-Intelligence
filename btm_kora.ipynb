# %%
# !pip install gmplot
import pandas as pd 
import gmplot
import pandas as pd
import requests
import time

# %%
traffic_koramangla_voosh = pd.read_csv('timings_kora1.csv')

# %%
traffic_sarjapur_voosh=pd.read_csv('timings_sarjapur.csv')
traffic_hsr_voosh=pd.read_csv('hsr from voosh .csv')
traffic_marathalli_voosh=pd.read_csv('Marathalli from voosh.csv')
traffic_belandur_voosh=pd.read_csv('bellandur from voosh.csv')

# %%
traffic_btm_voosh=pd.read_csv("check 4km btm.csv")

# %% [markdown]
# BTM HSR

# %%
apikey = 'AIzaSyAE6DIL0N8NlCvk2El_qo2C8gFmijXRjl0'

gmap = gmplot.GoogleMapPlotter.from_geocode(
    "Bengaluru, India", apikey=apikey)



for i in range(len(traffic_btm_voosh)):
    lat = traffic_btm_voosh["Latitude"][i]
    lon = traffic_btm_voosh["Longitude"][i]
    time = traffic_btm_voosh["19_00_voosh"][i]
    category = traffic_btm_voosh["Category"][i]
    name = traffic_btm_voosh['Region'][i]
    title1=str(lat)+","+str(lon)
    info_box_template = """
                        <dl>
                        <dt>lat</dt><dd>{lat}</dd>
                        <dt>lon</dt><dd>{lon}</dd>
                        </dl>
                        """
    if int(time) <=7:
          gmap.marker(lat, lon, color='green',
                title=title1, precision=7, draggable=False)
    elif int(time) >7 and time<=10:
      gmap.marker(lat, lon, color='yellow',
                title=title1, precision=7, draggable=False)
    elif int(time) >10 and time<=13:
      gmap.marker(lat, lon, color='orange',
                title=title1, precision=7, draggable=False)
    elif int(time) >13 and time<=17:
          gmap.marker(lat, lon, color='blue',
                title=title1, precision=7, draggable=False)
    else:
          continue
      #gmap.marker(lat, lon, color='red',
      #          title=name, precision=7, draggable=False)
 



# for kitchen lat lon voosh

for i in range(len(traffic_hsr_voosh)):
    lat = traffic_hsr_voosh["Latitude"][i]
    lon = traffic_hsr_voosh["Longitude"][i]
    time = traffic_hsr_voosh["19_00_voosh"][i]
    category = traffic_hsr_voosh["Category"][i]
    name = traffic_hsr_voosh['Region'][i]
    title1=str(lat)+","+str(lon)
    if int(time) <=7:
          gmap.marker(lat, lon, color='magenta',
                title=title1, precision=7, draggable=False)
    elif int(time) >7 and time<=10:
      gmap.marker(lat, lon, color='purple',
                title=title1, precision=7, draggable=False)
    elif int(time) >10 and time<=13:
      gmap.marker(lat, lon, color='pink',
                title=title1, precision=7, draggable=False)
    elif int(time) >13 and time<=17:
          gmap.marker(lat, lon, color='#FFFFFF',
                title=title1, precision=7, draggable=False)
    else:
          continue
      #gmap.marker(lat, lon, color='red',
      #          title=name, precision=7, draggable=False)


btm_store=(12.9195281, 77.6151523)
hsr_store=(12.9173789, 77.6514320)
marathalli_store=(12.957570,77.714530)
bellandur_store=(12.9258265, 77.7001271)
latitude_list=[12.949850,12.887050]
longitude_list=[77.635233,77.631367]

ta=str(12.949850)+","+str(77.635233)
tb=str(12.887050)+","+str(77.631367)
gmap.marker(12.949850, 77.635233,color='red',title=('intersection:'+ta),precision=7,draggable=False)
gmap.marker(12.887050, 77.631367,color='red',title=('intersection:'+tb),precision=7,draggable=False)
gmap.plot( latitude_list, longitude_list, 'red',
                              edge_width = 5.5 )
gmap.marker(btm_store[0], btm_store[1], color='red',title='VOOSH',
                precision=7, draggable=False)
gmap.circle(btm_store[0], btm_store[1], 4000, edge_color='#ffffff')
gmap.marker(hsr_store[0], hsr_store[1], color='red',title='VOOSH',
                precision=7, draggable=False)
gmap.circle(hsr_store[0], hsr_store[1], 4000, edge_color='#ffffff')


gmap.draw("BTM_HSR.html")

# %% [markdown]
# marathalli and HSR

# %%
apikey = 'AIzaSyAE6DIL0N8NlCvk2El_qo2C8gFmijXRjl0'

gmap = gmplot.GoogleMapPlotter.from_geocode(
    "Bengaluru, India", apikey=apikey)



for i in range(len(traffic_belandur_voosh)):
    lat = traffic_belandur_voosh["Latitude"][i]
    lon = traffic_belandur_voosh["Longitude"][i]
    time = traffic_belandur_voosh["19_00_voosh"][i]
    category = traffic_belandur_voosh["Category"][i]
    name = traffic_belandur_voosh['Region'][i]
    title1=str(lat)+","+str(lon)
    info_box_template = """
                        <dl>
                        <dt>lat</dt><dd>{lat}</dd>
                        <dt>lon</dt><dd>{lon}</dd>
                        </dl>
                        """
    if int(time) <=7:
          gmap.marker(lat, lon, color='green',
                title=title1, precision=7, draggable=False)
    elif int(time) >7 and time<=10:
      gmap.marker(lat, lon, color='yellow',
                title=title1, precision=7, draggable=False)
    elif int(time) >10 and time<=13:
      gmap.marker(lat, lon, color='orange',
                title=title1, precision=7, draggable=False)
    elif int(time) >13 and time<=17:
          gmap.marker(lat, lon, color='blue',
                title=title1, precision=7, draggable=False)
    else:
          continue
      #gmap.marker(lat, lon, color='red',
      #          title=name, precision=7, draggable=False)
 



# for kitchen lat lon voosh

for i in range(len(traffic_hsr_voosh)):
    lat = traffic_hsr_voosh["Latitude"][i]
    lon = traffic_hsr_voosh["Longitude"][i]
    time = traffic_hsr_voosh["19_00_voosh"][i]
    category = traffic_hsr_voosh["Category"][i]
    name = traffic_hsr_voosh['Region'][i]
    title1=str(lat)+","+str(lon)
    if int(time) <=7:
          gmap.marker(lat, lon, color='magenta',
                title=title1, precision=7, draggable=False)
    elif int(time) >7 and time<=10:
      gmap.marker(lat, lon, color='purple',
                title=title1, precision=7, draggable=False)
    elif int(time) >10 and time<=13:
      gmap.marker(lat, lon, color='pink',
                title=title1, precision=7, draggable=False)
    elif int(time) >13 and time<=17:
          gmap.marker(lat, lon, color='#FFFFFF',
                title=title1, precision=7, draggable=False)
    else:
          continue
      #gmap.marker(lat, lon, color='red',
      #          title=name, precision=7, draggable=False)


btm_store=(12.9195281, 77.6151523)
hsr_store=(12.9173789, 77.6514320)
marathalli_store=(12.957570,77.714530)
bellandur_store=(12.9258265, 77.7001271)
latitude_list=[12.948017,12.895200]
longitude_list=[77.671017,77.680533]
ta=str(12.948017)+","+str(77.671017)
tb=str(12.895200)+","+str(77.680533)
gmap.marker(12.948017, 77.671017,color='red',title=('intersection:'+ta),precision=7,draggable=False)
gmap.marker(12.895200, 77.680533,color='red',title=('intersection:'+tb),precision=7,draggable=False)
gmap.plot( latitude_list, longitude_list, 'red',
                              edge_width = 5.5 )
gmap.marker(bellandur_store[0], bellandur_store[1], color='red',title='VOOSH',
                precision=7, draggable=False)
gmap.circle(bellandur_store[0], bellandur_store[1], 4000, edge_color='#ffffff')
gmap.marker(hsr_store[0], hsr_store[1], color='red',title='VOOSH',
                precision=7, draggable=False)
gmap.circle(hsr_store[0], hsr_store[1], 4000, edge_color='#ffffff')


gmap.draw("Bellandur_HSR.html")

# %% [markdown]
# Bellandur Marathalli

# %%
apikey = 'AIzaSyAE6DIL0N8NlCvk2El_qo2C8gFmijXRjl0'

gmap = gmplot.GoogleMapPlotter.from_geocode(
    "Bengaluru, India", apikey=apikey)



for i in range(len(traffic_belandur_voosh)):
    lat = traffic_belandur_voosh["Latitude"][i]
    lon = traffic_belandur_voosh["Longitude"][i]
    time = traffic_belandur_voosh["19_00_voosh"][i]
    category = traffic_belandur_voosh["Category"][i]
    name = traffic_belandur_voosh['Region'][i]
    title1=str(lat)+","+str(lon)
    info_box_template = """
                        <dl>
                        <dt>lat</dt><dd>{lat}</dd>
                        <dt>lon</dt><dd>{lon}</dd>
                        </dl>
                        """
    if int(time) <=7:
          gmap.marker(lat, lon, color='green',
                title=title1, precision=7, draggable=False)
    elif int(time) >7 and time<=10:
      gmap.marker(lat, lon, color='yellow',
                title=title1, precision=7, draggable=False)
    elif int(time) >10 and time<=13:
      gmap.marker(lat, lon, color='orange',
                title=title1, precision=7, draggable=False)
    elif int(time) >13 and time<=17:
          gmap.marker(lat, lon, color='blue',
                title=title1, precision=7, draggable=False)
    else:
          continue
      #gmap.marker(lat, lon, color='red',
      #          title=name, precision=7, draggable=False)
 



# for kitchen lat lon voosh

for i in range(len(traffic_marathalli_voosh)):
    lat = traffic_marathalli_voosh["Latitude"][i]
    lon = traffic_marathalli_voosh["Longitude"][i]
    time = traffic_marathalli_voosh["19_00_voosh"][i]
    category = traffic_marathalli_voosh["Category"][i]
    name = traffic_marathalli_voosh['Region'][i]
    title1=str(lat)+","+str(lon)
    if int(time) <=7:
          gmap.marker(lat, lon, color='magenta',
                title=title1, precision=7, draggable=False)
    elif int(time) >7 and time<=10:
      gmap.marker(lat, lon, color='purple',
                title=title1, precision=7, draggable=False)
    elif int(time) >10 and time<=13:
      gmap.marker(lat, lon, color='pink',
                title=title1, precision=7, draggable=False)
    elif int(time) >13 and time<=17:
          gmap.marker(lat, lon, color='#FFFFFF',
                title=title1, precision=7, draggable=False)
    else:
          continue
      #gmap.marker(lat, lon, color='red',
      #          title=name, precision=7, draggable=False)


btm_store=(12.9195281, 77.6151523)
hsr_store=(12.9173789, 77.6514320)
marathalli_store=(12.957570,77.714530)
bellandur_store=(12.9258265, 77.7001271)
latitude_list=[12.928800,12.954583]
longitude_list=[77.736867,77.677783]
ta=str(12.928800)+","+str(77.736867)
tb=str(12.954583)+","+str(77.677783)
gmap.marker(12.928800, 77.736867,color='red',title=('intersection:'+ta),precision=7,draggable=False)
gmap.marker(12.954583, 77.677783,color='red',title=('intersection:'+tb),precision=7,draggable=False)
gmap.plot( latitude_list, longitude_list, 'red',
                              edge_width = 5.5 )
gmap.marker(bellandur_store[0], bellandur_store[1], color='red',title='VOOSH',
                precision=7, draggable=False)
gmap.circle(bellandur_store[0], bellandur_store[1], 4000, edge_color='#ffffff')
gmap.marker(marathalli_store[0], marathalli_store[1], color='red',title='VOOSH',
                precision=7, draggable=False)
gmap.circle(marathalli_store[0], marathalli_store[1], 4000, edge_color='#ffffff')


gmap.draw("Bellandur_marathalli.html")
